# %% [markdown]
# ### Import Pandas Library

# %%
import pandas as pd

# %%
ecom = pd.read_csv('data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here

# %%
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# **Check the last 10 rows of the DataFrame.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541899    581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541899  12/9/2011 12:50       3.75     12680.0  France
# 541900  12/9/2011 12:50       3.75     12680.0  France
# 541901  12/9/2011 12:50       1.95     12680.0  France
# 541902  12/9/2011 12:50       1.95     12680.0  France
# 541903  12/9/2011 12:50       4.15     12680.0  France
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %% [markdown]
# **How many rows and columns are there?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# **Show the statistical measurements of ecom dataset**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
#std = standart deviation

# %%
#If mean value is less than std, in this case look for outliers. 
# outliers can be identified using boxplot

# %% [markdown]
# **Show the column names in dataset**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# **What is the average Unit Price?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
# 4.611113626083471

# %% [markdown]
# **What were the highest and lowest unit prices?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
# 38970.0

# %% [markdown]
# ![download.png](attachment:0bc30fda-456e-441d-8c09-e392692ccf44.png)![image.png](attachment:image.png)

# %%
#your code here
# Out:
# -11062.06

# %%
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# Write a code to display unitprice less than 0.

# %%
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# **Check missing values in each column**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
ecom.isnull().sum().sum()
#1454 + 135080
# Out:
# 136534

# %%
#How many rows and column are there?
# Out:
# (541909, 8)

# %%
ecom.shape[0]
#Number of rows in data
# Out:
# 541909

# %% [markdown]
# ### Below code displays ratio of null values to entire rows in dataset.

# %%
ecom.isnull().sum().sum()/ecom.shape[0]*100
#percentage of null rows in this dataset
# Out:
# 25.195005065426113

# %%
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# #### As you can see, there are only around %25 of null values.

# %%
#When Description column is null then CustomerId is also null.

# %%
##Fill in null values

# %% [markdown]
# #### Check the shape of your dataset before dropping null values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
# (541909, 8)

# %% [markdown]
# **Drop null values. Use "inplace=True" argument**

# %%
#your code here

# %% [markdown]
# #### Check the shape of your dataset after dropping null values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
# (406829, 8)

# %% [markdown]
# **List the country names and number of records belongs to each country**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#your code here
# Out:
# United Kingdom          361878
# Germany                   9495
# France                    8491
# EIRE                      7485
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               1877
# Portugal                  1480
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     17
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# **How many records are as Country United Kingdom?**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#your code here
# Out:
# InvoiceNo      361878
# StockCode      361878
# Description    361878
# Quantity       361878
# InvoiceDate    361878
# UnitPrice      361878
# CustomerID     361878
# Country        361878
# dtype: int64

# %% [markdown]
# ### Whats the average Unit Price without United Kingdom?

# %% [markdown]
# 4.611113626083471

# %%
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 26       12/1/2010 8:45       3.75     12583.0  France
# 27       12/1/2010 8:45       3.75     12583.0  France
# 28       12/1/2010 8:45       3.75     12583.0  France
# 29       12/1/2010 8:45       0.85     12583.0  France
# 30       12/1/2010 8:45       0.65     12583.0  France
# ...                 ...        ...         ...     ...
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France
#
# [44951 rows x 8 columns]

# %%
# Out:
# 5.1065093101384

# %% [markdown]
# --Whats the average Unit Price in United Kingdom?

# %%
# Out:
# 3.2560068973474823

# %% [markdown]
# -Whats the highest Unit Price in United Kingdom?

# %%
# Out:
# 38970.0

# %% [markdown]
# ### Average UnitPrice per Country

# %%
# Out:
# Country
# Australia                 3.220612
# Austria                   4.243192
# Bahrain                   4.644118
# Belgium                   3.644335
# Brazil                    4.456250
# Canada                    6.030331
# Channel Islands           4.932124
# Cyprus                    6.302363
# Czech Republic            2.938333
# Denmark                   3.256941
# EIRE                      5.110699
# European Community        4.820492
# Finland                   5.448705
# France                    5.049021
# Germany                   3.966930
# Greece                    4.885548
# Iceland                   2.644011
# Israel                    3.650000
# Italy                     4.831121
# Japan                     2.276145
# Lebanon                   5.387556
# Lithuania                 2.841143
# Malta                     5.244173
# Netherlands               2.738317
# Norway                    6.012026
# Poland                    4.170880
# Portugal                  8.736392
# RSA                       4.277586
# Saudi Arabia              2.411000
# Singapore               109.645808
# Spain                     4.987544
# Sweden                    3.910887
# Switzerland               3.499521
# USA                       2.216426
# United Arab Emirates      3.380735
# United Kingdom            3.256007
# Unspecified               3.200820
# Name: UnitPrice, dtype: float64

# %% [markdown]
# ##### Should look into Unspecified country

# %%
# Out:
# Country
# USA             2.216426
# Japan           2.276145
# Saudi Arabia    2.411000
# Iceland         2.644011
# Netherlands     2.738317
# Name: UnitPrice, dtype: float64

# %%
# Out:
# Country
# Singapore    109.645808
# Portugal       8.736392
# Cyprus         6.302363
# Canada         6.030331
# Norway         6.012026
# Name: UnitPrice, dtype: float64

# %% [markdown]
# ### Investiagete country Singapore

# %%
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 406404   C571750         M                       Manual        -1
# 406406    571751         M                       Manual         1
# 144831   C548830         M                       Manual        -1
# 144826    548813         M                       Manual         1
# 406407    571751         M                       Manual         1
# 406405   C571750         M                       Manual        -1
# 144829    548820         M                       Manual         1
# 144834   C548834         M                       Manual        -1
# 144828    548813         M                       Manual         1
# 144833   C548830         M                       Manual        -1
# 144827    548813         M                       Manual         1
# 144832   C548830         M                       Manual        -1
# 144825    548813         M                       Manual         1
# 144830   C548830         M                       Manual        -1
# 70795     542102     22655  VINTAGE RED KITCHEN CABINET         2
#
#              InvoiceDate  UnitPrice  CustomerID    Country
# 406404  10/19/2011 11:16    3949.32     12744.0  Singapore
# 406406  10/19/2011 11:18    3949.32     12744.0  Singapore
# 144831    4/4/2011 13:08    2382.92     12744.0  Singapore
# 144826    4/4/2011 13:03    2382.92     12744.0  Singapore
# 406407  10/19/2011 11:18    2118.74     12744.0  Singapore
# 406405  10/19/2011 11:16    2118.74     12744.0  Singapore
# 144829    4/4/2011 13:04    2053.07     12744.0  Singapore
# 144834    4/4/2011 13:09    2053.07     12744.0  Singapore
# 144828    4/4/2011 13:03    1252.95     12744.0  Singapore
# 144833    4/4/2011 13:08    1252.95     12744.0  Singapore
# 144827    4/4/2011 13:03     239.30     12744.0  Singapore
# 144832    4/4/2011 13:08     239.30     12744.0  Singapore
# 144825    4/4/2011 13:03     162.60     12744.0  Singapore
# 144830    4/4/2011 13:08     162.60     12744.0  Singapore
# 70795    1/25/2011 13:26     125.00     12744.0  Singapore

# %% [markdown]
# Should look into Unspecified country

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 282744    561658     22846           BREAD BIN DINER STYLE RED          1
# 308810    564051     23007               SPACEBOY BABY GIFT SET         1
# 308808    564051     23008             DOLLY GIRL BABY GIFT SET         1
# 308801    564051     22839      3 TIER CAKE TIN GREEN AND CREAM         1
# 308802    564051     22838        3 TIER CAKE TIN RED AND CREAM         1
# ...          ...       ...                                  ...       ...
# 282733    561658     35968  FOLK ART METAL HEART T-LIGHT HOLDER         5
# 282754    561658     85212      MINI PAINTED GARDEN DECORATION         12
# 282763    561658     85213       MINI  ZINC GARDEN DECORATIONS         12
# 282783    561658     16012           FOOD/DRINK SPONGE STICKERS        24
# 282823    561661    79063C    RETRO PILL BOX KEY CHAIN,THE KING         1
#
#             InvoiceDate  UnitPrice  CustomerID      Country
# 282744  7/28/2011 16:06      16.95     12743.0  Unspecified
# 308810  8/22/2011 13:32      16.95     14265.0  Unspecified
# 308808  8/22/2011 13:32      16.95     14265.0  Unspecified
# 308801  8/22/2011 13:32      14.95     14265.0  Unspecified
# 308802  8/22/2011 13:32      14.95     14265.0  Unspecified
# ...                 ...        ...         ...          ...
# 282733  7/28/2011 16:06       0.38     12743.0  Unspecified
# 282754  7/28/2011 16:06       0.29     12743.0  Unspecified
# 282763  7/28/2011 16:06       0.29     12743.0  Unspecified
# 282783  7/28/2011 16:06       0.21     12743.0  Unspecified
# 282823  7/28/2011 16:21       0.19     12743.0  Unspecified
#
# [244 rows x 8 columns]

# %% [markdown]
# **Create a column named Total which shows the total amount of spend using UnitPrice and Quantity ?**

# %% [markdown]
# Hint: You can search online "create new column using other columns pandas"
# ("https://sparkbyexamples.com/pandas/pandas-add-column-based-on-another-column/")
# <p> Here is an example: df["NewColumnName"] = df["Column"] * df["Column"] <p\>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here

# %% [markdown]
# ### Total spending by country

# %% [markdown]
# ![image.png](attachment:1a05b869-81ed-4b18-99b9-038223e858d6.png)

# %%
#average age for boston celtics 
#df.groupby("Team")["age"].mean()

# %%
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     250285.220
# European Community         1291.750
# Finland                   22326.740
# France                   196712.840
# Germany                  221698.210
# Greece                     4710.520
# Iceland                    4310.000
# Israel                     6994.250
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# Poland                     7213.140
# Portugal                  29059.810
# RSA                        1002.310
# Saudi Arabia                131.170
# Singapore                  9120.390
# Spain                     54774.580
# Sweden                    36595.910
# Switzerland               55739.400
# USA                        1730.920
# United Arab Emirates       1902.280
# United Kingdom          6767873.394
# Unspecified                2667.070
# Name: Total, dtype: float64

# %%
#sort to get top 5 total spending countries
# Out:
# Country
# United Kingdom    6767873.394
# Netherlands        284661.540
# EIRE               250285.220
# Germany            221698.210
# France             196712.840
# Name: Total, dtype: float64

# %%
#sort to get least 5 spending countries
# Out:
# Country
# Brazil            1143.60
# RSA               1002.31
# Czech Republic     707.72
# Bahrain            548.40
# Saudi Arabia       131.17
# Name: Total, dtype: float64

# %%
# Out:
# Country
# Saudi Arabia       131.17
# Bahrain            548.40
# Czech Republic     707.72
# RSA               1002.31
# Brazil            1143.60
# Name: Total, dtype: float64

# %% [markdown]
# ### Average spending by country

# %%
#average top 5 total spending per country
# Out:
# Country
# Netherlands    120.059696
# Australia      108.877895
# Japan           98.716816
# Sweden          79.211926
# Denmark         48.247147
# Name: Total, dtype: float64

# %%
#average least 5 total spending per country
# Out:
# Country
# USA                5.948179
# Unspecified       10.930615
# Saudi Arabia      13.117000
# RSA               17.281207
# United Kingdom    18.702086
# Name: Total, dtype: float64

# %%
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %% [markdown]
# ### Highest Total by Customer in sum and average

# %%
# Out:
# CustomerID
# 14646.0    279489.02
# Name: Total, dtype: float64

# %%
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 37952     539491     21981       PACK OF 12 WOODLAND TISSUES         12
# 37953     539491     21986   PACK OF 12 PINK POLKADOT TISSUES        12
# 37954     539491     22720  SET OF 3 CAKE TINS PANTRY DESIGN          2
# 37955     539491     21931             JUMBO STORAGE BAG SUKI         1
# 37956     539491     22613        PACK OF 20 SPACEBOY NAPKINS         2
# ...          ...       ...                                ...       ...
# 534958    581176     22908      PACK OF 20 NAPKINS RED APPLES        96
# 534959    581176     22907   PACK OF 20 NAPKINS PANTRY DESIGN        96
# 534960    581176     22029             SPACEBOY BIRTHDAY CARD        72
# 534961    581176     22712                   CARD DOLLY GIRL         72
# 537783    581338     23344          JUMBO BAG 50'S CHRISTMAS        140
#
#              InvoiceDate  UnitPrice  CustomerID      Country   Total
# 37952   12/20/2010 10:09       0.29     14646.0  Netherlands    3.48
# 37953   12/20/2010 10:09       0.29     14646.0  Netherlands    3.48
# 37954   12/20/2010 10:09       4.95     14646.0  Netherlands    9.90
# 37955   12/20/2010 10:09       1.95     14646.0  Netherlands    1.95
# 37956   12/20/2010 10:09       0.85     14646.0  Netherlands    1.70
# ...                  ...        ...         ...          ...     ...
# 534958   12/7/2011 15:19       0.72     14646.0  Netherlands   69.12
# 534959   12/7/2011 15:19       0.72     14646.0  Netherlands   69.12
# 534960   12/7/2011 15:19       0.36     14646.0  Netherlands   25.92
# 534961   12/7/2011 15:19       0.36     14646.0  Netherlands   25.92
# 537783   12/8/2011 12:12       1.79     14646.0  Netherlands  250.60
#
# [2085 rows x 9 columns]

# %%
# Out:
# CustomerID
# 15195.0    3861.0
# 13135.0    3096.0
# 17846.0    2033.1
# Name: Total, dtype: float64

# %%
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 533812    581115     22413  METAL SIGN TAKE IT OR LEAVE IT       1404
#
#             InvoiceDate  UnitPrice  CustomerID         Country   Total
# 533812  12/7/2011 12:20       2.75     15195.0  United Kingdom  3861.0

# %%
# Out:
#        InvoiceNo StockCode           Description  Quantity      InvoiceDate  \
# 206121    554868     22197  SMALL POPCORN HOLDER      4300  5/27/2011 10:52
#
#         UnitPrice  CustomerID         Country   Total
# 206121       0.72     13135.0  United Kingdom  3096.0

# %%
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 343000    566927         M      Manual         1  9/15/2011 15:20     2033.1
#
#         CustomerID         Country   Total
# 343000     17846.0  United Kingdom  2033.1

# %% [markdown]
# **Which Country spend least in total?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %%
# Out:
# Country
# United Kingdom    6767873.394
# Name: Total, dtype: float64

# %% [markdown]
# **What is the max Total spending in whole dataset and show the records of that spending ?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here

# %% [markdown]
# **How many people who live in Spain spend more than average Total ?**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#your code here 2 filtering 1)spain and 2)avg

# %% [markdown]
# **Show total spending amount according to the Countries**

# %% [markdown]
# **Calculate average of spending according to country with apply function?**

# %% [markdown]
# # Congrats!
